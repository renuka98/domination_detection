# %%
import os
import argparse
import numpy as np
import pandas as pd
import sys
#sort the data with the help of users

# %%
node_folder =  'wikidata/'
timestamp_col='revtime'
df_complete = pd.read_csv(node_folder + "wiki_consolidated.csv")
df_complete['revtime'] = pd.to_datetime(df_complete['revtime'])
df_complete
# Out:
#         Unnamed: 0   username        revid                   revtime  \
# 0                4   Swiftscw  535370277.0 2013-01-28 17:21:30+00:00
# 1               26      Azkle  535906972.0 2013-01-31 19:50:17+00:00
# 2               27      Azkle  536604313.0 2013-02-04 23:37:02+00:00
# 3               28      Azkle  536612442.0 2013-02-05 00:42:14+00:00
# 4               29      Azkle  536613048.0 2013-02-05 00:47:04+00:00
# ...            ...        ...          ...                       ...
# 572706       22983  Dinkjunky  621772798.0 2014-08-18 13:50:54+00:00
# 572707       22984  Guptav657  619784717.0 2014-08-04 08:08:23+00:00
# 572708       22985  Guptav657  619785154.0 2014-08-04 08:13:46+00:00
# 572709       22986  Guptav657  619785219.0 2014-08-04 08:14:34+00:00
# 572710       22987  Guptav657  619785315.0 2014-08-04 08:15:34+00:00
#
#                                                 pagetitle  isReverted  \
# 0                       Wikipedia:Requests for undeletion       False
# 1       Wikipedia:Training/For students/Training feedback       False
# 2                                                 Netflix       False
# 3                                             Alan Turing       False
# 4                                             Alan Turing       False
# ...                                                   ...         ...
# 572706                                   Joseph John Issa       False
# 572707                                     User:Guptav657       False
# 572708                                     User:Guptav657       False
# 572709                                     User:Guptav657       False
# 572710                                     User:Guptav657       False
#
#        revertTime  cluebotRevert  stiki_score  stiki_REP_USER
# 0               -            0.0     0.000000             0.0
# 1               -            0.0     0.000000             0.0
# 2               -            0.0     0.118157             0.0
# 3               -            0.0     0.082944             0.0
# 4               -            0.0     0.082944             0.0
# ...           ...            ...          ...             ...
# 572706          -            0.0     0.000000             0.0
# 572707          -            0.0     0.000000             0.0
# 572708          -            0.0     0.000000             0.0
# 572709          -            0.0     0.000000             0.0
# 572710          -            0.0     0.000000             0.0
#
# [572711 rows x 10 columns]

# %%
#sort the # of users by distinct pages and get the top 200 users.
df_complete= df_complete[~df_complete['pagetitle'].str.contains("Wikipedia")]
print(df_complete['pagetitle'].nunique())
df_page_edits =  df_complete.groupby('username')['pagetitle'].agg(['nunique'])
df_page_edits = df_page_edits.sort_values(['nunique'], ascending=False, kind='mergesort')
user_list = list(df_page_edits.index.unique())
print(user_list[:200])

# %%
import matplotlib.pyplot as plt
hist = df_page_edits.hist(column='nunique', bins=50)
df_page_edits.to_csv(node_folder + "wiki_num_users.csv")

# %%
from numpy import genfromtxt
words = genfromtxt('wikidata/wiki_data_users.txt')
print(words)
# Out:
# [497. 494. 494. ...   1.   1.   1.]

# %%
import pylab
pylab.rcParams['xtick.major.pad']='8'
pylab.rcParams['ytick.major.pad']='8'
#pylab.rcParams['font.sans-serif']='Arial'

from matplotlib import rc
rc('font', family='sans-serif')
rc('font', size=10.0)
rc('text', usetex=False)


from matplotlib.font_manager import FontProperties

panel_label_font = FontProperties().copy()
panel_label_font.set_weight("bold")
panel_label_font.set_size(12.0)
panel_label_font.set_family("sans-serif")

# %%
# %pylab inline
import powerlaw


data = words

fit = powerlaw.Fit(data, discrete=True)
#print(fit.)
####
figCCDF = fit.plot_pdf(color='r', linewidth=3, label="Pages edited count fit")
fit.power_law.plot_pdf(color='b', linestyle='--', linewidth=2,label="Power law fit",  ax=figCCDF)
#fit.plot_ccdf(color='r', linewidth=2, ax=figCCDF)
#fit.power_law.plot_ccdf(color='r', linestyle='--', ax=figCCDF)
####
figCCDF.set_ylabel(u"p(X)")
figCCDF.set_xlabel(r"count of distinct pages edited by user")
#handles, labels = fig.get_legend_handles_labels()
#figCCDF.legend(handles, labels, loc=2)

figname = 'FigCCDF'
savefig(figname+'.eps', bbox_inches='tight')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\conda\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['pylab', 'rc']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# Calculating best minimal value for power law fit

# %%
#get all pages that have been edited by the users in user_list
min_list = user_list[:50]
df_limited_data = df_complete[df_complete.username.isin(min_list)]
df_limited_data
# Out:
#         Unnamed: 0        username        revid                   revtime  \
# 26607        23359  Hoppeduppeanut  538974927.0 2013-02-19 02:50:34+00:00
# 26608        23360  Hoppeduppeanut  538975868.0 2013-02-19 02:57:19+00:00
# 26609        23361  Hoppeduppeanut  538978642.0 2013-02-19 03:16:43+00:00
# 26610        23362  Hoppeduppeanut  538990812.0 2013-02-19 05:03:19+00:00
# 26611        23363  Hoppeduppeanut  538990940.0 2013-02-19 05:04:36+00:00
# ...            ...             ...          ...                       ...
# 558081        8358        Poveglia  623574945.0 2014-08-31 13:39:34+00:00
# 558082        8359        Poveglia  623575207.0 2014-08-31 13:42:01+00:00
# 558083        8360        Poveglia  623575264.0 2014-08-31 13:42:33+00:00
# 558084        8361        Poveglia  623575361.0 2014-08-31 13:43:35+00:00
# 558085        8362        Poveglia  623575526.0 2014-08-31 13:45:29+00:00
#
#                                     pagetitle  isReverted  \
# 26607   List of million-selling game consoles        True
# 26608   List of million-selling game consoles       False
# 26609                User talk:24.126.214.219       False
# 26610                User talk:198.91.217.200       False
# 26611      WWE World Heavyweight Championship       False
# ...                                       ...         ...
# 558081                  Víctor Aguirre-Torres       False
# 558082                      Billie Ray Martin       False
# 558083                                   Dust       False
# 558084              Equitable Tourism Options       False
# 558085                   Bojan Hadzihalilovic       False
#
#                   revertTime  cluebotRevert  stiki_score  stiki_REP_USER
# 26607   2013-02-19T02:57:19Z            0.0     0.321912             0.0
# 26608                      -            0.0     0.217040             0.0
# 26609                      -            0.0     0.000000             0.0
# 26610                      -            0.0     0.000000             0.0
# 26611                      -            0.0     0.186639             0.0
# ...                      ...            ...          ...             ...
# 558081                     -            0.0     0.000000             0.0
# 558082                     -            0.0     0.000000             0.0
# 558083                     -            0.0     0.000000             0.0
# 558084                     -            0.0     0.000000             0.0
# 558085                     -            0.0     0.000000             0.0
#
# [24101 rows x 10 columns]

# %%
pages_by_max_users = list(df_limited_data.pagetitle.unique())
print(len(pages_by_max_users))
# Out:
# 19912

# %%
df_page_user = df_complete[df_complete.pagetitle.isin(pages_by_max_users)]
#df_temp = df_page_user.groupby('pagetitle')['username'].agg(['nunique'])
#df_temp = df_temp.sort_values(['nunique'], ascending=False, kind='mergesort')
df_page_user
print(len(df_page_user.username.unique()))
#df_temp
# Out:
# 1686

# %%
df_with_user = df_page_user.groupby('pagetitle')['stiki_score'].agg(['mean', 'median'])

df_page_no_user = df_page_user[~df_page_user['username'].isin(min_list)]
df_page_no_user
# Out:
#         Unnamed: 0                username        revid  \
# 13             640             Laurenwking  537492820.0
# 14             656             Laurenwking  543572465.0
# 15             657             Laurenwking  543653856.0
# 16             693             Laurenwking  554192273.0
# 34            1418               Sannybear  534120201.0
# ...            ...                     ...          ...
# 572280       22557               Harshvg16  622183853.0
# 572281       22558               Harshvg16  622183936.0
# 572553       22830                 Isanaht  619585075.0
# 572638       22915  Nothingknewunderthesun  620962699.0
# 572639       22916  Nothingknewunderthesun  620962912.0
#
#                          revtime                           pagetitle  \
# 13     2013-02-10 04:44:12+00:00                   User talk:Klortho
# 14     2013-03-12 05:57:17+00:00                   User talk:Klortho
# 15     2013-03-12 16:37:45+00:00                   User talk:Klortho
# 16     2013-05-08 21:33:05+00:00                   User talk:Klortho
# 34     2013-01-21 06:00:40+00:00               User talk:Jimbo Wales
# ...                          ...                                 ...
# 572280 2014-08-21 11:26:36+00:00  WWE World Heavyweight Championship
# 572281 2014-08-21 11:27:42+00:00  WWE World Heavyweight Championship
# 572553 2014-08-02 19:33:17+00:00                 User talk:Wizardman
# 572638 2014-08-12 20:22:49+00:00               User talk:STATicVapor
# 572639 2014-08-12 20:24:39+00:00               User talk:STATicVapor
#
#         isReverted revertTime  cluebotRevert  stiki_score  stiki_REP_USER
# 13           False          -            0.0     0.000000             0.0
# 14           False          -            0.0     0.000000             0.0
# 15           False          -            0.0     0.000000             0.0
# 16           False          -            0.0     0.000000             0.0
# 34           False          -            0.0     0.000000             0.0
# ...            ...        ...            ...          ...             ...
# 572280       False          -            0.0     0.143318             0.0
# 572281       False          -            0.0     0.266784             0.0
# 572553       False          -            0.0     0.000000             0.0
# 572638       False          -            0.0     0.000000             0.0
# 572639       False          -            0.0     0.000000             0.0
#
# [8017 rows x 10 columns]

# %%
df_without_user = df_page_no_user.groupby('pagetitle')['stiki_score'].agg(['mean', 'median'])
df_without_user.rename(columns={'mean':'mean_without_user', 'median':'median_without_user'}, inplace=True)

df_final = df_with_user.merge(df_without_user, on='pagetitle', how='left')
df_final
# Out:
#                               mean    median  mean_without_user  \
# pagetitle
# "Arderin"                 0.000000  0.000000                NaN
# "Awesome"                 0.071733  0.071733                NaN
# "Costs Follow the Event"  0.000000  0.000000                NaN
# "G" Division DMP          0.000000  0.000000                NaN
# "banner" ads              0.000000  0.000000                NaN
# ...                            ...       ...                ...
# Šėta                      0.110957  0.110957                NaN
# Żurrieq                   0.025308  0.025308                NaN
# Žasliai                   0.110957  0.110957                NaN
# Κ-opioid receptor         0.163635  0.163635           0.188314
# “Black Swan” event        0.000000  0.000000                NaN
#
#                           median_without_user
# pagetitle
# "Arderin"                                 NaN
# "Awesome"                                 NaN
# "Costs Follow the Event"                  NaN
# "G" Division DMP                          NaN
# "banner" ads                              NaN
# ...                                       ...
# Šėta                                      NaN
# Żurrieq                                   NaN
# Žasliai                                   NaN
# Κ-opioid receptor                    0.188314
# “Black Swan” event                        NaN
#
# [19912 rows x 4 columns]

# %%
df_final.to_csv(node_folder + "wiki_hypothesis2.csv")
